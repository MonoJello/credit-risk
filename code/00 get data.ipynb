# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo 
from utils import describe as des

# %% [markdown]
# # get data

# %%
statlog_german_credit_data = fetch_ucirepo(id=144)

# %%
type(statlog_german_credit_data)
# Out:
# ucimlrepo.dotdict.dotdict

# %%
X = statlog_german_credit_data.data.features 
y = statlog_german_credit_data.data.targets

# %%
X.head()
# Out:
#   Attribute1  Attribute2 Attribute3 Attribute4  Attribute5 Attribute6  \
# 0        A11           6        A34        A43        1169        A65
# 1        A12          48        A32        A43        5951        A61
# 2        A14          12        A34        A46        2096        A61
# 3        A11          42        A32        A42        7882        A61
# 4        A11          24        A33        A40        4870        A61
#
#   Attribute7  Attribute8 Attribute9 Attribute10  Attribute11 Attribute12  \
# 0        A75           4        A93        A101            4        A121
# 1        A73           2        A92        A101            2        A121
# 2        A74           2        A93        A101            3        A121
# 3        A74           2        A93        A103            4        A122
# 4        A73           3        A93        A101            4        A124
#
#    Attribute13 Attribute14 Attribute15  Attribute16 Attribute17  Attribute18  \
# 0           67        A143        A152            2        A173            1
# 1           22        A143        A152            1        A173            1
# 2           49        A143        A152            1        A172            2
# 3           45        A143        A153            1        A173            2
# 4           53        A143        A153            2        A173            2
#
#   Attribute19 Attribute20
# 0        A192        A201
# 1        A191        A201
# 2        A191        A201
# 3        A191        A201
# 4        A191        A201

# %%
y.head()
# Out:
#    class
# 0      1
# 1      2
# 2      1
# 3      1
# 4      2

# %%
y.groupby('class').size()
# Out:
# class
# 1    700
# 2    300
# dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Attribute1   1000 non-null   str
#  1   Attribute2   1000 non-null   int64
#  2   Attribute3   1000 non-null   str
#  3   Attribute4   1000 non-null   str
#  4   Attribute5   1000 non-null   int64
#  5   Attribute6   1000 non-null   str
#  6   Attribute7   1000 non-null   str
#  7   Attribute8   1000 non-null   int64
#  8   Attribute9   1000 non-null   str
#  9   Attribute10  1000 non-null   str
#  10  Attribute11  1000 non-null   int64
#  11  Attribute12  1000 non-null   str
#  12  Attribute13  1000 non-null   int64
#  13  Attribute14  1000 non-null   str
#  14  Attribute15  1000 non-null   str
#  15  Attribute16  1000 non-null   int64
#  16  Attribute17  1000 non-null   str
#  17  Attribute18  1000 non-null   int64
#  18  Attribute19  1000 non-null   str
#  19  Attribute20  1000 non-null   str
# dtypes: int64(7), str(13)
# memory usage: 156.4 KB

# %% [markdown]
# # rename columns from variable descriptions

# %%
# Rename the 20 columns in your dataframe
X.columns = [
    "checking_account_status",
    "duration_months",
    "credit_history",
    "purpose",
    "credit_amount",
    "savings_account_bonds",
    "employment_since",
    "installment_rate_percent",
    "personal_status_sex",
    "other_debtors_guarantors",
    "residence_since",
    "property",
    "age_years",
    "other_installment_plans",
    "housing",
    "existing_credits_at_bank",
    "job",
    "liable_persons",
    "telephone",
    "foreign_worker"
]

# %% [markdown]
# # map categorical values to definitions

# %% [raw]
# mappings = {
#     "checking_account_status": {
#         "A11": "<0 DM",
#         "A12": "0-200 DM",
#         "A13": ">=200 DM",
#         "A14": "no account",
#     },
#
#     "credit_history": {
#         "A30": "no credit/all paid",
#         "A31": "bank credit paid",
#         "A32": "current credit paid",
#         "A33": "past payment delays",
#         "A34": "critical/other credit",
#     },
#
#     "purpose": {
#         "A40": "new car",
#         "A41": "used car",
#         "A42": "furniture/equipment",
#         "A43": "radio/TV",
#         "A44": "appliances",
#         "A45": "repairs",
#         "A46": "education",
#         "A47": "vacation",
#         "A48": "retraining",
#         "A49": "business",
#         "A410": "other",
#     },
#
#     "savings_account_bonds": {
#         "A61": "<100 DM",
#         "A62": "100-500 DM",
#         "A63": "500-1000 DM",
#         "A64": ">=1000 DM",
#         "A65": "unknown/no savings",
#     },
#
#     "employment_since": {
#         "A71": "unemployed",
#         "A72": "<1 year",
#         "A73": "1-4 years",
#         "A74": "4-7 years",
#         "A75": ">=7 years",
#     },
#
#     "personal_status_sex": {
#         "A91": "male divorced",
#         "A92": "female married/divorced",
#         "A93": "male single",
#         "A94": "male married/widowed",
#         "A95": "female single",
#     },
#
#     "other_debtors_guarantors": {
#         "A101": "none",
#         "A102": "co-applicant",
#         "A103": "guarantor",
#     },
#
#     "property": {
#         "A121": "real estate",
#         "A122": "life insurance/building society",
#         "A123": "car/other property",
#         "A124": "unknown/no property",
#     },
#
#     "other_installment_plans": {
#         "A141": "bank",
#         "A142": "stores",
#         "A143": "none",
#     },
#
#     "housing": {
#         "A151": "rent",
#         "A152": "own",
#         "A153": "free",
#     },
#
#     "job": {
#         "A171": "unemployed/unskilled nonresident",
#         "A172": "unskilled resident",
#         "A173": "skilled employee/official",
#         "A174": "manager/self-employed/highly qualified",
#     },
#
#     "telephone": {
#         "A191": "none",
#         "A192": "registered",
#     },
#
#     "foreign_worker": {
#         "A201": "yes",
#         "A202": "no",
#     },
# }

# %%
mappings = {
    "checking_account_status": {
        "A11": "lt0 DM",
        "A12": "0 to 200 DM",
        "A13": "ge200 DM",
        "A14": "no account",
    },

    "credit_history": {
        "A30": "no credit or all paid",
        "A31": "bank credit paid",
        "A32": "current credit paid",
        "A33": "past payment delays",
        "A34": "critical or other credit",
    },

    "purpose": {
        "A40": "new car",
        "A41": "used car",
        "A42": "furniture or equipment",
        "A43": "radio or TV",
        "A44": "appliances",
        "A45": "repairs",
        "A46": "education",
        "A47": "vacation",
        "A48": "retraining",
        "A49": "business",
        "A410": "other",
    },

    "savings_account_bonds": {
        "A61": "lt100 DM",
        "A62": "100 to 500 DM",
        "A63": "500 to 1000 DM",
        "A64": "ge1000 DM",
        "A65": "unknown or no savings",
    },

    "employment_since": {
        "A71": "unemployed",
        "A72": "lt1 year",
        "A73": "1 to 4 years",
        "A74": "4 to 7 years",
        "A75": "ge7 years",
    },

    "personal_status_sex": {
        "A91": "male divorced",
        "A92": "female married or divorced",
        "A93": "male single",
        "A94": "male married or widowed",
        "A95": "female single",
    },

    "other_debtors_guarantors": {
        "A101": "none",
        "A102": "co applicant",
        "A103": "guarantor",
    },

    "property": {
        "A121": "real estate",
        "A122": "life insurance or building society",
        "A123": "car or other property",
        "A124": "unknown or no property",
    },

    "other_installment_plans": {
        "A141": "bank",
        "A142": "stores",
        "A143": "none",
    },

    "housing": {
        "A151": "rent",
        "A152": "own",
        "A153": "free",
    },

    "job": {
        "A171": "unemployed or unskilled nonresident",
        "A172": "unskilled resident",
        "A173": "skilled employee or official",
        "A174": "manager or self employed or highly qualified",
    },

    "telephone": {
        "A191": "none",
        "A192": "registered",
    },

    "foreign_worker": {
        "A201": "yes",
        "A202": "no",
    },
}

# %%
for column, mapping in mappings.items():
    X[column] = X[column].map(mapping)

# %%
X.head()
# Out:
#   checking_account_status  duration_months            credit_history  \
# 0                  lt0 DM                6  critical or other credit
# 1             0 to 200 DM               48       current credit paid
# 2              no account               12  critical or other credit
# 3                  lt0 DM               42       current credit paid
# 4                  lt0 DM               24       past payment delays
#
#                   purpose  credit_amount  savings_account_bonds  \
# 0             radio or TV           1169  unknown or no savings
# 1             radio or TV           5951               lt100 DM
# 2               education           2096               lt100 DM
# 3  furniture or equipment           7882               lt100 DM
# 4                 new car           4870               lt100 DM
#
#   employment_since  installment_rate_percent         personal_status_sex  \
# 0        ge7 years                         4                 male single
# 1     1 to 4 years                         2  female married or divorced
# 2     4 to 7 years                         2                 male single
# 3     4 to 7 years                         2                 male single
# 4     1 to 4 years                         3                 male single
#
#   other_debtors_guarantors  residence_since  \
# 0                     none                4
# 1                     none                2
# 2                     none                3
# 3                guarantor                4
# 4                     none                4
#
#                              property  age_years other_installment_plans  \
# 0                         real estate         67                    none
# 1                         real estate         22                    none
# 2                         real estate         49                    none
# 3  life insurance or building society         45                    none
# 4              unknown or no property         53                    none
#
#   housing  existing_credits_at_bank                           job  \
# 0     own                         2  skilled employee or official
# 1     own                         1  skilled employee or official
# 2     own                         1            unskilled resident
# 3    free                         1  skilled employee or official
# 4    free                         2  skilled employee or official
#
#    liable_persons   telephone foreign_worker
# 0               1  registered            yes
# 1               1        none            yes
# 2               2        none            yes
# 3               2        none            yes
# 4               2        none            yes

# %%
y.groupby('class').size()
# Out:
# class
# 1    700
# 2    300
# dtype: int64

# %%
X['bad'] = y['class'].astype(int) - 1

# %%
X.groupby('bad').size()
# Out:
# bad
# 0    700
# 1    300
# dtype: int64

# %% [markdown]
# # save data

# %%
X.shape
# Out:
# (1000, 21)

# %%
X.to_pickle("../data/00_df_data.pkl")

# %%
import hashlib

with open("../data/00_df_data.pkl", "rb") as file:
    file_hash = hashlib.sha256(file.read()).hexdigest()

print(file_hash)
# Out:
# 492f2f588f5eed51d16e8cbeb03aaf6c852abf1623cc8f9ca5222ea44ef0445a

# %% [markdown]
# # split into training and test

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(
    X,
    test_size=0.50,
    # test_size=0.20,
    random_state=42,
    stratify=X["bad"]
)

# %% [markdown]
# # compare samples

# %%
pd.set_option("display.max_rows", None)

# %%
des.compare_datasets(train_df,test_df)
# Out:
#                                                        train      test  \
# checking_account_status = no account                  39.800    39.000
# checking_account_status = lt0 DM                      28.400    26.400
# checking_account_status = 0 to 200 DM                 25.000    28.800
# checking_account_status = ge200 DM                     6.800     5.800
# duration_months                                       20.832    20.974
# credit_history = critical or other credit             28.400    30.200
# credit_history = current credit paid                  51.600    54.400
# credit_history = past payment delays                  10.400     7.200
# credit_history = bank credit paid                      5.600     4.200
# credit_history = no credit or all paid                 4.000     4.000
# purpose = used car                                    10.600    10.000
# purpose = furniture or equipment                      17.200    19.000
# purpose = new car                                     25.600    21.200
# purpose = radio or TV                                 27.800    28.200
# purpose = business                                     9.800     9.600
# purpose = other                                        0.400     2.000
# purpose = appliances                                   1.600     0.800
# purpose = repairs                                      2.600     1.800
# purpose = education                                    4.000     6.000
# purpose = retraining                                   0.400     1.400
# credit_amount                                       3015.726  3526.790
# savings_account_bonds = lt100 DM                      59.600    61.000
# savings_account_bonds = unknown or no savings         18.200    18.400
# savings_account_bonds = ge1000 DM                      5.000     4.600
# savings_account_bonds = 100 to 500 DM                 11.200     9.400
# savings_account_bonds = 500 to 1000 DM                 6.000     6.600
# employment_since = ge7 years                          27.600    23.000
# employment_since = 1 to 4 years                       33.200    34.600
# employment_since = 4 to 7 years                       15.600    19.200
# employment_since = lt1 year                           18.400    16.000
# employment_since = unemployed                          5.200     7.200
# installment_rate_percent                               3.018     2.928
# personal_status_sex = female married or divorced      29.600    32.400
# personal_status_sex = male single                     56.600    53.000
# personal_status_sex = male married or widowed          8.600     9.800
# personal_status_sex = male divorced                    5.200     4.800
# other_debtors_guarantors = none                       90.800    90.600
# other_debtors_guarantors = co applicant                4.600     3.600
# other_debtors_guarantors = guarantor                   4.600     5.800
# residence_since                                        2.862     2.828
# property = car or other property                      35.400    31.000
# property = real estate                                27.800    28.600
# property = unknown or no property                     15.200    15.600
# property = life insurance or building society         21.600    24.800
# age_years                                             35.624    35.468
# other_installment_plans = none                        82.400    80.400
# other_installment_plans = bank                        12.800    15.000
# other_installment_plans = stores                       4.800     4.600
# housing = rent                                        16.600    19.200
# housing = own                                         73.200    69.400
# housing = free                                        10.200    11.400
# existing_credits_at_bank                               1.392     1.422
# job = manager or self employed or highly qualified    15.000    14.600
# job = skilled employee or official                    63.600    62.400
# job = unskilled resident                              19.600    20.400
# job = unemployed or unskilled nonresident              1.800     2.600
# liable_persons                                         1.140     1.170
# telephone = registered                                39.000    41.800
# telephone = none                                      61.000    58.200
# foreign_worker = yes                                  96.000    96.600
# foreign_worker = no                                    4.000     3.400
# bad                                                    0.300     0.300
#
#                                                     percent_difference
# checking_account_status = no account                         -2.010050
# checking_account_status = lt0 DM                             -7.042254
# checking_account_status = 0 to 200 DM                        15.200000
# checking_account_status = ge200 DM                          -14.705882
# duration_months                                               0.681644
# credit_history = critical or other credit                     6.338028
# credit_history = current credit paid                          5.426357
# credit_history = past payment delays                        -30.769231
# credit_history = bank credit paid                           -25.000000
# credit_history = no credit or all paid                        0.000000
# purpose = used car                                           -5.660377
# purpose = furniture or equipment                             10.465116
# purpose = new car                                           -17.187500
# purpose = radio or TV                                         1.438849
# purpose = business                                           -2.040816
# purpose = other                                             400.000000
# purpose = appliances                                        -50.000000
# purpose = repairs                                           -30.769231
# purpose = education                                          50.000000
# purpose = retraining                                        250.000000
# credit_amount                                                16.946632
# savings_account_bonds = lt100 DM                              2.348993
# savings_account_bonds = unknown or no savings                 1.098901
# savings_account_bonds = ge1000 DM                            -8.000000
# savings_account_bonds = 100 to 500 DM                       -16.071429
# savings_account_bonds = 500 to 1000 DM                       10.000000
# employment_since = ge7 years                                -16.666667
# employment_since = 1 to 4 years                               4.216867
# employment_since = 4 to 7 years                              23.076923
# employment_since = lt1 year                                 -13.043478
# employment_since = unemployed                                38.461538
# installment_rate_percent                                     -2.982107
# personal_status_sex = female married or divorced              9.459459
# personal_status_sex = male single                            -6.360424
# personal_status_sex = male married or widowed                13.953488
# personal_status_sex = male divorced                          -7.692308
# other_debtors_guarantors = none                              -0.220264
# other_debtors_guarantors = co applicant                     -21.739130
# other_debtors_guarantors = guarantor                         26.086957
# residence_since                                              -1.187980
# property = car or other property                            -12.429379
# property = real estate                                        2.877698
# property = unknown or no property                             2.631579
# property = life insurance or building society                14.814815
# age_years                                                    -0.437907
# other_installment_plans = none                               -2.427184
# other_installment_plans = bank                               17.187500
# other_installment_plans = stores                             -4.166667
# housing = rent                                               15.662651
# housing = own                                                -5.191257
# housing = free                                               11.764706
# existing_credits_at_bank                                      2.155172
# job = manager or self employed or highly qualified           -2.666667
# job = skilled employee or official                           -1.886792
# job = unskilled resident                                      4.081633
# job = unemployed or unskilled nonresident                    44.444444
# liable_persons                                                2.631579
# telephone = registered                                        7.179487
# telephone = none                                             -4.590164
# foreign_worker = yes                                          0.625000
# foreign_worker = no                                         -15.000000
# bad                                                           0.000000

# %%
pd.reset_option("display.max_rows")

# %% [markdown]
# # save training and test samples

# %%
train_df.to_pickle("../data/00_df_train.pkl")
test_df.to_pickle("../data/00_df_test.pkl")

# %%
train_df.groupby('bad').size()
# Out:
# bad
# 0    350
# 1    150
# dtype: int64

# %%
test_df.groupby('bad').size()
# Out:
# bad
# 0    350
# 1    150
# dtype: int64
